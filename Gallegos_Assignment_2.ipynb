# %% [markdown]
# <a href="https://colab.research.google.com/github/jgalleg4/git_test/blob/main/Gallegos_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot
from shapely.geometry import MultiLineString, LineString, Point
import math

# %%
data = np.loadtxt("travelTimes_example_2019.txt", delimiter=';',skiprows=1, usecols=[5,6,7,8])
data
# Out:
# array([[33., 11., 44., 38.],
#        [71., 24., 17., 49.],
#        [52., 52., 69., 48.],
#        [68., 48., 67., 34.],
#        [11., 76., 43., 24.],
#        [28., 36., 84., 53.],
#        [49., 19., 30., 48.],
#        [47., 56., 20., 28.],
#        [66., 78., 71., 43.],
#        [64., 49., 32., 89.],
#        [51., 23., 61., 16.],
#        [28., 37., 82., 67.],
#        [90., 41., 65., 58.],
#        [37., 84., 50., 48.],
#        [20., 35., 46., 58.],
#        [41., 77., 57., 49.],
#        [31., 36., 16., 57.],
#        [40., 80., 14., 45.],
#        [40., 57., 22., 21.],
#        [25., 17., 76., 22.],
#        [85., 31., 64., 22.],
#        [56., 70., 14., 23.],
#        [27., 25., 55., 44.],
#        [41., 31., 76., 54.],
#        [86., 74., 71., 45.],
#        [52., 62., 50., 23.],
#        [21., 90., 69., 55.],
#        [42., 87., 61., 52.],
#        [31., 12., 81., 34.],
#        [79., 50., 80., 65.],
#        [67., 61., 85., 83.],
#        [36., 68., 25., 27.],
# ...

# %%
from shapely.geometry import MultiLineString, LineString, Point

lines = []

for item in data:
  start_point = Point(item[0], item[1])
  end_point = Point(item[2], item[3])
  line = LineString((start_point,end_point))
  lines.append(line)

multi_line = MultiLineString(lines)
multi_line

# %%
lines

# %%
od_strings = []

# %%
print(lines)
print(od_strings)
# Out:
# [<shapely.geometry.linestring.LineString object at 0x7f7e80e45b50>, <shapely.geometry.linestring.LineString object at 0x7f7e80e459d0>, <shapely.geometry.linestring.LineString object at 0x7f7e80e453d0>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45a50>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45790>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45a90>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45850>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45110>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45d10>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45910>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45e90>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45b10>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45bd0>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45e50>, <shapely.geometry.linestring.LineString object at 0x7f7e80e
# ...

# %%
idx = np.random.randint(0,40)
print(idx)
# Out:
# 21

# %%
print(lines[idx])
# Out:
# LINESTRING (56 70, 14 23)

# %%
def changeList(idx):
  item = lines[idx]
  od_strings.append(item)
  lines.remove(item)
  print("List1:",lines)
  print("Index:",idx)
  print("List2:",od_strings)

# %%
print(lines)
print(od_strings)
# Out:
# [<shapely.geometry.linestring.LineString object at 0x7f7e80e45b50>, <shapely.geometry.linestring.LineString object at 0x7f7e80e459d0>, <shapely.geometry.linestring.LineString object at 0x7f7e80e453d0>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45a50>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45790>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45a90>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45850>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45110>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45d10>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45910>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45e90>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45b10>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45bd0>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45e50>, <shapely.geometry.linestring.LineString object at 0x7f7e80e
# ...

# %%
while lines != []:
  l = len(lines)
  n = np.random.randint(0,l)
  changeList(n)
# Out:
# List1: [<shapely.geometry.linestring.LineString object at 0x7f7e80e45b50>, <shapely.geometry.linestring.LineString object at 0x7f7e80e459d0>, <shapely.geometry.linestring.LineString object at 0x7f7e80e453d0>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45a50>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45790>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45a90>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45850>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45110>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45d10>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45910>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45e90>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45b10>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45bd0>, <shapely.geometry.linestring.LineString object at 0x7f7e80e45e50>, <shapely.geometry.linestring.LineString object at 0x
# ...

# %%
print(lines)
print(od_strings)
# Out:
# []
# ...
